# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import neo_api_client as kapi
import threading
import json

# %%
from neo_api_client import NeoAPI
df=pd.DataFrame()
def on_message(message):
    
    formatted_json=json.dumps(message, indent=2)
    print(formatted_json)
    global a
    a=pd.DataFrame.from_dict(formatted_json)
    print(type(message))
    flattened_data = []
    for item in formatted_json['data']:
        ohlc_data = item.pop('ohlc')
        item.update(ohlc_data)
        flattened_data.append(item)
    # Create a DataFrame
    global df
    df = pd.DataFrame(flattened_data)
    print(df)
#def on_message(message):
    #formatted_json=json.dumps(message, indent=2)
    #print(formatted_json)
    
def on_error(error_message):
    print(error_message)

def on_close(message):
    print(message)
    
def on_open(message):
    print(message)

# %%
client.quotes(instrument_tokens=tokens[:98])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 client.quotes(instrument_tokens=tokens[:98])
#
# NameError: name 'client' is not defined

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
consumer_key="hGZIbGDe7RPxoRD3cZ3UJaGftUUa"
consumer_secret="j24xLx4_1Kbl4acvpc8iDo2hHcIa"
access_token='eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..TkDyBcpj0Tgucallvb_hEOH9DdbzJ6q5G2rGPFqKO-XnzDbAm7GehnjMjLNKa8kThEZLj9o9iyGWJ2fO9CmEAF_kLku6okDfSuZEemQswKw2aYzGOR_onXPKc_qAPIVEIfTV9bDN-kHbdEEQVQ8VH4LwNqndzXkHRjDOdghMKvknNZGGkLjDTJ9HCM9XYlVkMQ8wLDoP1K8agM73Iannk_xwMtnNhICvxxFCpIDefhXCC7C64JSzhRS18-Yr1Fe8lCn29t3BYVkcf1z9gl-jE_xFmNHSrsszd2Ceu-FtNAj2XXSbHIVfayRJ68FVTY_Qe0Pp99riwM3l_0IdVuAeSw'
mobilenumber='+919936053873'
password="21900@Agr"
mpin=

# %%
client = NeoAPI(consumer_key=consumer_key,
                consumer_secret=consumer_secret,
                environment='prod',
                access_token=access_token,
                neo_fin_key=None
               )

# %%
client.on_message = on_message  # called when message is received from websocket
client.on_error = on_error  # called when any error or exception occurs in code or websocket
client.on_close = on_close  # called when websocket connection is closed
client.on_open = on_open  # called when websocket successfully connects

# %%
client.login( mobilenumber=mobilenumber,
             password=password)
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..UhPK68nrtvXqw_ytKwpjaA_JEDQsRwSjGTMOh588NsuKpWq0PfWfx0ct6c4jXLGn4DvKEydYhWgQaAfMklWbalON7vQ4TyVX_76Q5m1s9uUr9PPGnibPb49F9WRL3p9RqC1-biV1V6zkaRRtoIMshb8fbRcG9n53TiYiDbLbabvyXPCHv5EASC69Qgik93LmkifbkEQhiKLxcd4YoxK3HYlbNXQ6K_yZ-44ksyFD26qHsVj0zXYQ1hlBvxPbEtUDrrmQ0fay1fneNxxXRAcb76EJAAIfrnvbjKZGhQX6eWJ71n2emEsMIxut7gTzlocD93nLy9BaPW8A-nwOMr87zg',
#   'sid': '9bcd32ff-f1ad-4299-86ac-e0781ae95875',
#   'rid': 'e5f964a9-52f0-4a74-aac5-5ee390746712',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1746124081', 'lastUpdatedTS': '1746124081'},
# ...

# %%
client.session_2fa(OTP="9905")
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..bNtjNxzMc7vrM1jWSeTkvxb-QzpSiezx-CKgCDOP2ihn7BY8700FDOsJbBQf81hBvZnW8247PJyyDEO5VwDTgih3CZ43jqbTKzIAcF7GAGKBwaQ-HtM9ZyS_hM5zzK_bZ9BEVkUV-pJpuHRe19MlNbEYICBsJoysmQokZyqRy1q0T5GfZY58qOtiWOCkTRtuPVkBAjWU3tzp7L7aaH2J62ZZacL4Frz4OgNAfMeN8o6ryh64dnTdo4cHuvUxkUFDBqZM2wUcyVMqhicIxNtg2zSyUPaTnT4l4F8SGPRIrnhduDLdyYYtYChMeSgtwE2pDB9XpqDC0XeNKA4XTJ-aXA',
#   'sid': '9bcd32ff-f1ad-4299-86ac-e0781ae95875',
#   'rid': 'e5f964a9-52f0-4a74-aac5-5ee390746712',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1746124081', 'lastUpdatedTS': '1746124081'},
# ...

# %%
master_list_equity=client.scrip_master(exchange_segment='NSE')
master_list_nfo=client.scrip_master(exchange_segment='NFO')
master_list_equity,master_list_nfo
# Out:
# ('https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-05-01/transformed/nse_cm.csv',
#  'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-05-01/transformed/nse_fo.csv')

# %%
equ=pd.read_csv(master_list_equity)  # There is the presence of all the stock available , from kotak neo 
stock=pd.read_csv('/Users/Macbook/Desktop/n500.csv')  # This is the nifty 500 stock download from nse site
nifty500=equ[equ['pSymbolName'].isin(stock['Symbol'])]
nifty500=nifty500[nifty500['pGroup']=='EQ'].reset_index(drop=True)
nifty500
# Out:
#      pSymbol pGroup pExchSeg  pInstType pSymbolName     pTrdSymbol
# 0       6545     EQ   nse_cm        NaN       NYKAA       NYKAA-EQ  \
# 1          7     EQ   nse_cm        NaN    AARTIIND    AARTIIND-EQ
# 2      13404     EQ   nse_cm        NaN       SUNTV       SUNTV-EQ
# 3      13409     EQ   nse_cm        NaN        GPIL        GPIL-EQ
# 4       6596     EQ   nse_cm        NaN  SONATSOFTW  SONATSOFTW-EQ
# ..       ...    ...      ...        ...         ...            ...
# 485    13285     EQ   nse_cm        NaN      M&MFIN      M&MFIN-EQ
# 486    13305     EQ   nse_cm        NaN  CENTURYPLY  CENTURYPLY-EQ
# 487    13310     EQ   nse_cm        NaN         KEI         KEI-EQ
# 488    13332     EQ   nse_cm        NaN   SOLARINDS   SOLARINDS-EQ
# 489    13359     EQ   nse_cm        NaN    KFINTECH    KFINTECH-EQ
#
#      pOptionType pScripRefKey         pISIN  pAssetCode  ...  dGenDen
# 0            NaN        NYKAA  INE388Y01029         NaN  ...        1  \
# ...

# %%
dir(client)
# Out:
# ['NeoWebSocket',
#  '_NeoAPI__on_close',
#  '_NeoAPI__on_error',
#  '_NeoAPI__on_message',
#  '_NeoAPI__on_open',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'api_client',
#  'cancel_order',
#  'check_callbacks',
#  'configuration',
#  'help',
#  'holdings',
#  'limits',
#  'login',
#  'logout',
#  'margin_required',
#  'modify_order',
#  'on_close',
#  'on_error',
#  'on_message',
#  'on_open',
#  'order_history',
#  'order_report',
#  'place_order',
#  'positions',
#  'quotes',
#  'scrip_master',
#  'search_scrip',
#  'session_2fa',
#  'set_neowebsocket_callbacks',
#  'subscribe',
# ...

# %%
# this is to create the tokens to get the data 
tokens=[{"instrument_token": f"{sym}", "exchange_segment": "nse_cm"} for sym in nifty500['pSymbol']] 
tokens
# Out:
# [{'instrument_token': '6545', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '7', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13404', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13409', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '6596', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13451', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13491', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '6656', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13501', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13517', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13538', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13560', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13587', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '13', 'exchange_segment': 'nse_cm'},
#  {'instrument_token': '22', 'exchange_segment': 'nse_cm'},
# ...

# %%
client.quotes(instrument_tokens=tokens[:98],quote_type='ohlc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 client.quotes(instrument_tokens=tokens[:98],quote_type='ohlc')
#
# File ~/anaconda3/lib/python3.11/site-packages/neo_api_client/neo_api.py:578, in NeoAPI.quotes(self, instrument_tokens, quote_type, isIndex, session_token, sid, server_id)
#     575     raise ValueError("Error! Login or Kindly pass the SID token to proceed further")
#     577 if not server_id and not self.configuration.serverId:
# --> 578     raise ValueError("Error! Login or Kindly pass the server ID token to proceed further")
#     580 if(not session_token and self.configuration.edit_token):
#     581     session_token = self.configuration.edit_token
#
# ValueError: Error! Login or Kindly pass the server ID token to proceed further

# %%
inst_tokens = [{"instrument_token": "11536", "exchange_segment": "nse_cm"},
               {"instrument_token": "1594", "exchange_segment": "nse_cm"},
               {"instrument_token": "11915", "exchange_segment": "nse_cm"},
               {"instrument_token": "13245", "exchange_segment": "nse_cm"},
               {"instrument_token": "1333", "exchange_segment": "nse_cm"}]
client.quotes(instrument_tokens=inst_tokens)



    # Get live feed data
client.subscribe(instrument_tokens=instrument_tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 11
#       6 client.quotes(instrument_tokens=inst_tokens)
#      10     # Get live feed data
# ---> 11 client.subscribe(instrument_tokens=instrument_tokens)
#
# NameError: name 'instrument_tokens' is not defined
# The Session has been Opened!
# {
#   "type": "quotes",
#   "data": [
#     {
#       "last_traded_price": "0.00",
#       "buy_price": "0.00",
#       "sell_price": "0.00",
#       "buy_quantity": "0",
#       "lower_circuit_limit": "95.00",
#       "upper_circuit_limit": "105.00",
#       "multiplier": "1",
#       "precision": "2",
#       "instrument_token": "13245",
#       "exchange_segment": "nse_cm",
#       "trading_symbol": "76KA32-SG",
#       "request_type": "SNAP",
#       "ohlc": {
#         "open": "0.00",
#         "high": null,
#         "low": null,
#         "close": null
#       }
# ...

# %%
def websock():
    inst_tokens = [{"instrument_token": "1333", "exchange_segment": "nse_cm"}]
    client.subscribe(instrument_tokens=inst_tokens)

# %%
thread=threading.Thread(target=websock)

# %%
thread.start()
# Out:
# The Session has been Opened!
# Raw message: {'type': 'stock_feed', 'data': [{'ftm0': '02/01/1970 02:53:56', 'dtm1': '06/06/1971 00:27:09', 'fdtm': '10/10/2024 12:44:56', 'ltt': '10/10/2024 12:44:55', 'v': '5722812', 'ltp': '1649.55', 'ltq': '29', 'tbq': '1409547', 'tsq': '437350', 'bp': '1649.15', 'sp': '1649.55', 'bq': '21', 'bs': '40', 'ap': '1641.52', 'lo': '1632.50', 'h': '1652.50', 'lcl': '1469.85', 'ucl': '1796.45', 'yh': '1794.00', 'yl': '1363.55', 'op': '1639.00', 'c': '1633.15', 'mul': '1', 'prec': '2', 'cng': '16.40', 'nc': '1.00', 'to': '9394110354.24', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'ts': 'HDFCBANK-EQ', 'request_type': 'SNAP'}]}
# The Session has been Closed!
# the JSON object must be str, bytes or bytearray, not dict

# %%
thread.stop()
# Out:
# {'type': 'stock_feed', 'data': [{'ftm0': '01/01/1970 16:31:56', 'dtm1': '31/03/1971 06:57:35', 'ltq': '68', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 thread.stop()
#
# AttributeError: 'Thread' object has no attribute 'stop'
# {'type': 'stock_feed', 'data': [{'ftm0': '01/01/1970 16:31:59', 'dtm1': '31/03/1971 07:04:15', 'ltt': '10/10/2024 11:08:50', 'v': '3475789', 'ltp': '1638.00', 'ltq': '1', 'tbq': '330314', 'tsq': '422668', 'bp': '1638.00', 'sp': '1638.25', 'bq': '439', 'bs': '102', 'cng': '4.85', 'nc': '0.30', 'to': '5695601644.85', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# ...

# %%
def quotes():
    inst_tokens = [{"instrument_token": "1333", "exchange_segment": "nse_cm"}]
    client.quotes(instrument_tokens=instrument_tokens,quote_type='ohlc')
    time.sleep(1)
# Out:
# {'type': 'stock_feed', 'data': [{'ftm0': '01/01/1970 17:40:20', 'dtm1': '07/04/1971 14:10:57', 'fdtm': '10/10/2024 11:19:21', 'ltt': '10/10/2024 11:19:21', 'v': '3645856', 'ltq': '3', 'tbq': '363089', 'tsq': '433670', 'bq': '35', 'bs': '30', 'to': '5974464227.20', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# {'type': 'stock_feed', 'data': [{'ftm0': '01/01/1970 17:40:26', 'dtm1': '07/04/1971 14:24:18', 'fdtm': '10/10/2024 11:19:22', 'ltt': '10/10/2024 11:19:22', 'v': '3645948', 'ltp': '1640.15', 'ltq': '9', 'tbq': '363029', 'tsq': '434378', 'sp': '1640.75', 'bq': '26', 'bs': '77', 'cng': '7.00', 'nc': '0.43', 'to': '5974614987.60', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# {'type': 'stock_feed', 'data': [{'ftm0': '01/01/1970 17:40:29', 'dtm1': '07/04/1971 14:30:58', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# ...

# %%
print(5+1)
# Out:
# {'type': 'stock_feed', 'data': [{'ftm0': '01/01/1970 18:03:47', 'dtm1': '10/04/1971 02:53:18', 'fdtm': '10/10/2024 11:23:00', 'ltt': '10/10/2024 11:22:59', 'v': '3699890', 'ltp': '1641.00', 'ltq': '5', 'tbq': '407139', 'tsq': '461588', 'bq': '60', 'bs': '40', 'cng': '7.85', 'nc': '0.48', 'to': '6063120739.70', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# 6
# {'type': 'stock_feed', 'data': [{'ftm0': '01/01/1970 18:03:53', 'dtm1': '10/04/1971 03:06:38', 'ltt': '10/10/2024 11:23:00', 'v': '3700146', 'ltq': '78', 'tbq': '407282', 'tsq': '462141', 'bq': '147', 'bs': '118', 'to': '6063540254.58', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# ...

# %%
def on_message(message):
    global df
    data=json.load(message)
    if 'data' in data:
        new_row=pd.DataFrame(data['data'])
        df=pd.concat([df,new_row],ignore_index=True)
        print(df.tail(1))
# Out:
# {'type': 'stock_feed', 'data': [{'ftm0': '02/01/1970 00:59:44', 'dtm1': '24/05/1971 18:29:06', 'fdtm': '10/10/2024 12:27:17', 'ltt': '10/10/2024 12:27:17', 'v': '5496034', 'ltq': '25', 'tbq': '1414461', 'tsq': '433427', 'sp': '1649.85', 'bs': '35', 'to': '9020365802.50', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# {'type': 'stock_feed', 'data': [{'ftm0': '02/01/1970 00:59:47', 'dtm1': '24/05/1971 18:42:26', 'fdtm': '10/10/2024 12:27:18', 'ltt': '10/10/2024 12:27:18', 'v': '5496163', 'ltq': '1', 'tbq': '1411482', 'tsq': '433146', 'sp': '1649.80', 'bq': '172', 'bs': '42', 'to': '9020577523.75', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# {'type': 'stock_feed', 'data': [{'ftm0': '02/01/1970 00:59:50', 'dtm1': '24/05/1971 18:49:07', 'name': 'sf', 'tk': '1333', 'e': 'nse_cm', 'request_type': 'SUB'}]}
# ...

# %%
thread.start()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 thread.start()
#
# File ~/anaconda3/lib/python3.11/threading.py:952, in Thread.start(self)
#     949     raise RuntimeError("thread.__init__() not called")
#     951 if self._started.is_set():
# --> 952     raise RuntimeError("threads can only be started once")
#     954 with _active_limbo_lock:
#     955     _limbo[self] = self
#
# RuntimeError: threads can only be started once

# %%
equ[equ['pSymbolName']== 'TCS']
# Out:
#       pSymbol pGroup pExchSeg  pInstType pSymbolName pTrdSymbol  pOptionType
# 8072    11536     EQ   nse_cm        NaN         TCS     TCS-EQ          NaN  \
# 9243    12825     BL   nse_cm        NaN         TCS     TCS-BL          NaN
#
#      pScripRefKey         pISIN  pAssetCode  ...  dGenDen  dGenNum
# 8072          TCS  INE467B01029         NaN  ...        1        1  \
# 9243       TCS-BL  INE467B01029         NaN  ...        1        1
#
#      dPriceQuatation   dIssuerate   dPriceDen  dWarningQty   dIssueCapital
# 8072                0            0          1             0    3.618090e+09  \
# 9243                0            0          1             0    3.618090e+09
#
#       dExposureMargin   dMinRedemptionQty   lFreezeQty
# 8072                 0                   0       21708
# 9243                 0                   0    99999999
#
# [2 rows x 78 columns]

# %%
client.place_order(exchange_segment="nse_cm",
                   product="MIS",
                   price="498.25",
                   order_type="L",
                   quantity="1",
                   validity="DAY",
                   trading_symbol="ITC-EQ",
                   transaction_type="S",
                   amo="NO",
                   disclosed_quantity="0",
                   market_protection="0",
                   pf="N",
                   trigger_price="498.25",
                   tag="NONE")
# Out:
# {'stat': 'Ok',
#  'nOrdNo': '241014001621944',
#  'tid': 'server6_2528151',
#  'stCode': 200}

# %%
client.positions()
# Out:
# {'tid': 'server6_2555406',
#  'stat': 'Ok',
#  'stCode': 200,
#  'data': [{'buyAmt': '498.05',
#    'cfSellAmt': '0.00',
#    'prod': 'MIS',
#    'exSeg': 'nse_cm',
#    'sqrFlg': 'Y',
#    'actId': 'YD2HU',
#    'cfBuyQty': '0',
#    'hsUpTm': '2024/10/14 14:50:49',
#    'updRecvTm': 1728897649730473091,
#    'cfSellQty': '0',
#    'tok': '1660',
#    'upldPrc': '0.00',
#    'flBuyQty': '1',
#    'flSellQty': '1',
#    'sellAmt': '497.40',
#    'posFlg': 'true',
#    'cfBuyAmt': '0.00',
#    'stkPrc': '0.00',
#    'trdSym': 'ITC-EQ',
#    'sym': 'ITC',
#    'multiplier': '1',
#    'precision': '2',
#    'expDt': 'NA',
#    'type': 'NA',
#    'genNum': '1',
#    'series': 'EQ',
#    'prcNum': '1',
#    'genDen': '1',
#    'brdLtQty': 1,
#    'exp': '--',
#    'lotSz': '1',
#    'optTp': 'XX',
#    'prcDen': '1'}]}

# %%
client.trade_report()
# Out:
# {'tid': 'server6_2553443',
#  'stat': 'Ok',
#  'stCode': 200,
#  'data': [{'exOrdId': '1100000040976208',
#    'brkClnt': 'NA',
#    'cstFrm': 'C',
#    'actId': 'YD2HU',
#    'rmk': '--',
#    'fldQty': 1,
#    'flDt': '14-Oct-2024',
#    'avgPrc': '497.40',
#    'ordSrc': 'NA',
#    'algId': 'NA',
#    'locId': '111111111111100',
#    'prcTp': 'L',
#    'prod': 'MIS',
#    'exTm': '14-Oct-2024 14:50:20',
#    'nReqId': '1',
#    'exSeg': 'nse_cm',
#    'trdSym': 'ITC-EQ',
#    'GuiOrdId': '1728897620-831695-DLUPA0946K-ADMINAPI',
#    'flLeg': 1,
#    'rptTp': 'fill',
#    'usrId': 'DLUPA0946K',
#    'uSec': '838051',
#    'hsUpTm': '2024/10/14 14:51:26',
#    'updRecvTm': 1728897686213466564,
#    'ordGenTp': '--',
#    'flId': '206880507',
#    'flTm': '14:50:20',
#    'trnsTp': 'S',
#    'nOrdNo': '241014001634037',
#    'strategyCode': 'NA',
#    'algCat': 'NA',
#    'ordDur': 'DAY',
#    'boeSec': 1728897620,
#    'stkPrc': '0.00',
#    'sym': 'ITC',
#    'multiplier': '1',
# ...

# %%
client.limits()
# Out:
# {'AddPreExpMrgnMisPrsnt': '0.00',
#  'CurExpMrgnNrmlPrsnt': '0.00',
#  'CurPremiumNrmlPrsnt': '0.00',
#  'RmsPayOutAmt': '0.00',
#  'AdhocMargin': '0.00',
#  'MrgnScrpBsktCncPrsnt': '0.00',
#  'FoPremiumMisPrsnt': '0.00',
#  'tid': 'server4_2547484',
#  'MrgnVarNrmlPrsnt': '0.00',
#  'AmountUtilizedPrsnt': '0.00',
#  'SplMrgnMisPrsnt': '0.00',
#  'CurSpanMrgnNrmlPrsnt': '0.00',
#  'SlbmVarElm': '0.00',
#  'AuxRmsCollateral': '0.00',
#  'FoUnRlsMtomPrsnt': '0.00',
#  'AuxNotionalCash': '0.00',
#  'AuxAdhocMargin': '0.00',
#  'DaneLimit': '0.00',
#  'RmsMutualFundAmt': '0.00',
#  'RmsPayInAmt': '200.00',
#  'CurPremiumMisPrsnt': '0.00',
#  'SlbmLimit': '0',
#  'MarginWarningPrcntPrsnt': '49.93',
#  'MrgnVarMisPrsnt': '0.00',
#  'CurRlsMtomPrsnt': '0.00',
#  'RMSRequiredMargin': '0.00',
#  'ExposureMarginPrsnt': '0.00',
#  'NfospreadBenefit': '0.00',
#  'stCode': 200,
#  'CollateralValue': '0.00',
#  'AddMrgnNrmlPrsnt': '0.00',
#  'RmsCollateralMult': '0.00',
# ...

# %%
client.holdings()
# Out:
# {'data': []}

# %%
pip show websockets
# Out:
# Name: websockets
# Version: 13.1
# Summary: An implementation of the WebSocket Protocol (RFC 6455 & 7692)
# Home-page:
# Author:
# Author-email: Aymeric Augustin <aymeric.augustin@m4x.org>
# License: BSD-3-Clause
# Location: /Users/Macbook/anaconda3/lib/python3.11/site-packages
# Requires:
# Required-by: dhanhq, neo-api-client
# Note: you may need to restart the kernel to use updated packages.
